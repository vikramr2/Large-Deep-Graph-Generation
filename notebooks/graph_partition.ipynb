# %%
import csv
from pathlib import Path

# %%
network_id = 'amazon0302'

inp_network_fp = f'test_data/networks/orig/{network_id}/{network_id}_cleaned.tsv'
inp_clustering_fp = f'test_data/networks/orig/{network_id}/{network_id}_kaffpa_cc.tsv'

out_dir = Path(f'test_data/networks/syn/{network_id}/orig_subnetworks')
out_dir.mkdir(parents=True, exist_ok=True)

# %%
# Load clustering
all_clusters = set()
clustered_nodes = set()
node2cluster = dict()
cluster2nodes = dict()
with open(inp_clustering_fp, 'r') as f:
    reader = csv.reader(f, delimiter='\t')
    for v, c in reader:
        assert v not in clustered_nodes
        node2cluster[v] = c
        cluster2nodes.setdefault(c, set()).add(v)
        clustered_nodes.add(v)
        all_clusters.add(c)

# Load edgelist
all_nodes = set()
all_cc_edges = set()
all_co_edges = set()
all_oo_edges = set()
with open(inp_network_fp, 'r') as f:
    reader = csv.reader(f, delimiter='\t')
    for u, v in reader:
        all_nodes.add(u)
        all_nodes.add(v)
        if u in clustered_nodes and v in clustered_nodes:
            all_cc_edges.add((u, v))
        elif u in clustered_nodes or v in clustered_nodes:
            all_co_edges.add((u, v))
        else:
            all_oo_edges.add((u, v))

# Load outliers
outlier_nodes = all_nodes - clustered_nodes

# %%
subnetworks = dict()
n_edges_per_cluster = dict()
for c in all_clusters:
    subnetworks[c] = set()
    # Ignore all edges with at least one outlier
    for u, v in all_cc_edges:
        if u in outlier_nodes or v in outlier_nodes:
            continue
        if u in cluster2nodes[c] and v in cluster2nodes[c]:
            subnetworks[c].add((u, v))
    n_edges_per_cluster[c] = len(subnetworks[c])

# %%
# Export subnetworks
for c, edges in subnetworks.items():
    out_fp = out_dir / f'{c}.tsv'
    with open(out_fp, 'w') as f:
        writer = csv.writer(f, delimiter='\t')
        for u, v in edges:
            writer.writerow([u, v])
    print(f'Exported {len(edges)} edges to {out_fp}')
# Out:
# Exported 1652 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/48.tsv
# Exported 2384 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/66.tsv
# Exported 1266 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/65δ.tsv
# Exported 1429 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/137.tsv
# Exported 2601 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/60.tsv
# Exported 478 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/161δ.tsv
# Exported 1657 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/142.tsv
# Exported 2467 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/41.tsv
# Exported 1213 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/2.tsv
# Exported 3005 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/69.tsv
# Exported 1618 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/90.tsv
# Exported 2127 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/28.tsv
# Exported 1572 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/73.tsv
# Exported 913 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/4.tsv
# Exported 1495 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/22.tsv
# Exported 1678 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/136.tsv
# Exported 993 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/155δ.tsv
# Exported 561 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/100δ.tsv
# Exported 1294 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/106δ.tsv
# Exported 2073 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/91δ.tsv
# Exported 850 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/115δ.tsv
# Exported 1120 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/99δ.tsv
# Exported 2210 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/130.tsv
# Exported 1978 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/93.tsv
# Exported 1096 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/63.tsv
# Exported 1607 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/37.tsv
# Exported 934 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/128.tsv
# Exported 1731 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/35.tsv
# Exported 1201 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/75δ.tsv
# Exported 522 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/24δ.tsv
# Exported 1039 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/67δ.tsv
# Exported 2891 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/98.tsv
# Exported 1206 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/160.tsv
# Exported 1006 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/8.tsv
# Exported 1040 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/14δ.tsv
# Exported 1079 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/144.tsv
# Exported 1098 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/34δ.tsv
# Exported 2496 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/32δ.tsv
# Exported 1519 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/88δ.tsv
# Exported 777 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/16.tsv
# Exported 3189 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/104.tsv
# Exported 1437 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/79.tsv
# Exported 1184 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/101.tsv
# Exported 2793 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/42.tsv
# Exported 2019 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/147.tsv
# Exported 3319 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/92.tsv
# Exported 968 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/165.tsv
# Exported 1442 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/59.tsv
# Exported 1065 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/96.tsv
# Exported 828 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/77.tsv
# Exported 1000 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/19δ.tsv
# Exported 1470 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/20δ.tsv
# Exported 1259 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/62δ.tsv
# Exported 1959 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/33.tsv
# Exported 1279 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/29δ.tsv
# Exported 1534 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/107.tsv
# Exported 1775 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/45δ.tsv
# Exported 795 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/171.tsv
# Exported 2624 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/94.tsv
# Exported 1027 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/168.tsv
# Exported 1182 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/3.tsv
# Exported 3184 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/61.tsv
# Exported 1067 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/141.tsv
# Exported 982 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/166.tsv
# Exported 1721 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/31.tsv
# Exported 847 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/89.tsv
# Exported 794 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/145.tsv
# Exported 1857 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/64.tsv
# Exported 1358 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/13.tsv
# Exported 675 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/124.tsv
# Exported 1133 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/74.tsv
# Exported 3518 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/44.tsv
# Exported 1578 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/56δ.tsv
# Exported 1296 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/109.tsv
# Exported 1376 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/38δ.tsv
# Exported 1298 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/113.tsv
# Exported 865 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/159δ.tsv
# Exported 913 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/122.tsv
# Exported 3026 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/25.tsv
# Exported 1314 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/0δ.tsv
# Exported 3016 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/150.tsv
# Exported 1473 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/1.tsv
# Exported 2129 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/58.tsv
# Exported 2702 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/87.tsv
# Exported 797 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/123.tsv
# Exported 1032 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/154.tsv
# Exported 1290 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/68.tsv
# Exported 1634 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/6.tsv
# Exported 1117 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/139.tsv
# Exported 1703 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/72.tsv
# Exported 1531 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/71.tsv
# Exported 1018 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/51δ.tsv
# Exported 1711 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/118.tsv
# Exported 1592 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/12.tsv
# Exported 661 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/157.tsv
# Exported 2000 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/15.tsv
# Exported 2193 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/55.tsv
# Exported 1257 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/26.tsv
# Exported 1402 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/36.tsv
# Exported 834 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/103δ.tsv
# Exported 1433 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/50.tsv
# Exported 1246 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/53.tsv
# Exported 1227 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/163.tsv
# Exported 832 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/54δ.tsv
# Exported 917 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/52.tsv
# Exported 1059 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/21δ.tsv
# Exported 3043 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/153.tsv
# Exported 929 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/112δ.tsv
# Exported 857 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/7δ.tsv
# Exported 675 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/83.tsv
# Exported 958 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/125.tsv
# Exported 2747 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/17.tsv
# Exported 2312 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/133.tsv
# Exported 3038 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/39.tsv
# Exported 1168 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/156.tsv
# Exported 1395 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/11.tsv
# Exported 182 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/76δ.tsv
# Exported 2082 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/47δ.tsv
# Exported 1270 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/102.tsv
# Exported 3592 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/120.tsv
# Exported 1986 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/110.tsv
# Exported 2088 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/23δ.tsv
# Exported 1032 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/152δ.tsv
# Exported 1510 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/134.tsv
# Exported 532 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/127.tsv
# Exported 3824 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/158.tsv
# Exported 789 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/138δ.tsv
# Exported 732 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/116δ.tsv
# Exported 698 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/169.tsv
# Exported 977 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/43δ.tsv
# Exported 1132 edges to test_data/networks/syn/cit-HepPh/orig_subnetworks/148δ.tsv
